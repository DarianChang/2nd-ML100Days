# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #找的是heartattack的資料
# 1. 你選的這組資料為何重要
# 此組資料從一些醫療檢測所產生的資料中預測心臟病的發生機率高與低，由於心臟病的發生往往是徒然的，並且發生後若事前沒有做好預防性的處理，例如準備心臟病專用藥物等，
# 非常可能造成往生，我們可以從數據中去發現心臟病潛在患者，提前做好預防並降低死亡機率。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者是clevelend大學的資料庫，並有以下四種提供來源，是從四家醫院取得的臨床資料。
# 	1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
# 	2. University Hospital, Zurich, Switzerland: William Steinbrunn, M.D.
# 	3. University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D.
# 	4. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
#
# 3. 蒐集而來的資料型態為何
# age: int
# sex: int (1 = male, 0 = female)
# cp: int (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
# trestbps: int (mm Hg on admission to the hospital)
# chol: int
# fbs: int (> 120 mg/dl, 1 = true; 0 = false)
# restecg: int (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
# thalach: int
# exang: int (1 = yes; 0 = no)
# oldpeak: float ('ST' relates to positions on the ECG plot. See more here)
# slope: int (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
# ca: The number of major vessels (0-3)
# thal: int (3 = normal; 6 = fixed defect; 7 = reversable defect)
# target: Heart disease: int (0 = no, 1 = yes)
#
# 4. 這組資料想解決的問題如何評估
# 此組資料有提供一個欄位表示此病人是否得到心臟病（原本以整數值1~4作為表示但已簡化為1,0），因此可以從資料中去評估究竟哪種欄位的值出現提高時病人會提高得心臟病的機會。
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 假設業績=載客消費金額，以乘客的乘車位置預測可使司機優先前往地點，使顧客評分使用者滿意度去評比個別司機的滿意度，使用此兩個數據去與業績做相關分析。載客消費金額若與上述數據有高度相關，做進一步的分析如何改善兩者數據，例如時間與乘客乘車位置去調整各時段的司機費率使乘客等車時間減少，或進階分析顧客評分使用者滿意度去與司機汽車廠牌，學歷等作分析已招募更好的司機。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 乘車位置使用gps定位，顧客評分使用者滿意度為顧客使用線上問卷輸入。
# 3. 蒐集而來的資料型態為何
# 乘車位置為三位數加上二十位小數，使用者滿意度為一至十分。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 檢視使用者滿意度與載客金額之間的相關性，以及乘客的乘車位置與載客金額之間的相關性。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    return np.power(y-y_hat,2).mean()


def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE) )
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 217.707
# The Mean absolute error is 11.742
